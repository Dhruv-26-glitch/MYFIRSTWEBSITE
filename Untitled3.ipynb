# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv-26-glitch/MYFIRSTWEBSITE/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("students.csv")
df

print(df.shape)
print(df.columns)
print(df.index)
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())

db = pd.read_csv("students.csv")
db


print(df.isnull())
print(df.isnull().sum())
# df['Grade'].value_counts(dropna=False)
print(df.notna)
print(df.notnull)
print(df.nunique)
# Out:
# (5, 3)
# Index(['names', 'marks', 'grade'], dtype='object')
# RangeIndex(start=0, stop=5, step=1)
#    names  marks grade
# 0  dhruv   90.0     A
# 1    sam   70.0     B
# 2   riya   60.0     C
# 3    NaN   90.0     A
# 4  Kiran    NaN     B
#    names  marks grade
# 0  dhruv   90.0     A
# 1    sam   70.0     B
# 2   riya   60.0     C
# 3    NaN   90.0     A
# 4  Kiran    NaN     B
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   4 non-null      object
#  1   marks   4 non-null      float64
#  2   grade   5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 252.0+ bytes
# None
#        marks
# count    4.0
# mean    77.5
# std     15.0
# min     60.0
# 25%     67.5
# 50%     80.0
# 75%     90.0
# max     90.0
#    names  marks  grade
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# ...
